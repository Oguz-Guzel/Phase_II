# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.24/06

# %%
def doFitAndCreateWorkspace(fin,channel_name,nameout):

    fout = ROOT.TFile(nameout,"recreate")
    # output as a RooWorkspace
    rws = ROOT.RooWorkspace("HHWWgg","HHWWgg")

    # observable variable
    mass = ROOT.RooRealVar("mgg_%s"%channel_name,"invariant mass",125,100,180)
    getattr(rws,"import")(mass)

    # background model
    alpha = ROOT.RooRealVar("alpha_%s"%channel_name,"#alpha",-0.05,-0.2,0.01);
    expo = ROOT.RooExponential("exp_%s"%channel_name,"exponential function",mass,alpha);

    mch = fin.Get("Continuum_Bkg")
    dhbkg = ROOT.RooDataHist("mc_%s"%(channel_name),"obs data",ROOT.RooArgList(mass),mch)
    expo.fitTo(dhbkg)
    
    # make a nice plot just to check 
    c = ROOT.TCanvas()
    pl = mass.frame()
    dhbkg.plotOn(pl)
    expo.plotOn(pl)
    pl.Draw()
    c.SaveAs("background_fit_%s.pdf"%channel_name)
    getattr(rws,"import")(expo)

    # fit gaussians in a certain range
    mass.setRange("r1",123,127)

    # single-Higgs backgrounds & signal we'll assume each is a Gaussian
    for s in ["GGHH","GGH","VBFH","VH","ttH","tHq"]:
        mh    = ROOT.RooRealVar("mh_%s_%s"%(s,channel_name),"mean in GeV",125,123,127)
        sigma1 = ROOT.RooRealVar("sigma1_%s_%s"%(s,channel_name),"sigma1 in GeV",2.0,0.5,6)
        sigma2 = ROOT.RooRealVar("sigma2_%s_%s"%(s,channel_name),"sigma2 in GeV",4.0,0.5,9)
        gauss1 = ROOT.RooGaussian("gauss1_%s_%s"%(s,channel_name),"f1(m|M_{H},#sigma)",mass,mh,sigma1);
        gauss2 = ROOT.RooGaussian("gauss2_%s_%s"%(s,channel_name),"f2(m|M_{H},#sigma)",mass,mh,sigma2);
        frac   = ROOT.RooRealVar("frac_%s_%s"%(s,channel_name),"sigma1 in GeV",0.6,0.,1)
        gauss  = ROOT.RooAddPdf("gauss_%s_%s"%(s,channel_name),"",ROOT.RooArgList(gauss1,gauss2),ROOT.RooArgList(frac))
        th1   = fin.Get(s)
        dh1   = ROOT.RooDataHist("rdh_%s"%(s),"rdh_%s"%(s),ROOT.RooArgList(mass),th1)
        gauss.fitTo(dh1,ROOT.RooFit.Range("fitrange"))

        print(f"Results peak -> {s}, channel -> {channel_name}")
        mh.Print()
        sigma1.Print()
        sigma2.Print()
        print("---------------------------------")
        
        getattr(rws,"import")(gauss)

        # plot to check
        c = ROOT.TCanvas()
        pla = mass.frame()
        dh1.plotOn(pla)
        gauss.plotOn(pla)
        pla.Draw()
        c.SaveAs("signal_mc_fit_%s_%s.pdf"%(s,channel_name))
    
    for s in ["GGHH","GGH","VBFH","VH","ttH","tHq"]:
       # must set these parameters to constant for the limit setting
       rws.var("mh_%s_%s"%(s,channel_name)).setConstant(1)
       rws.var("sigma1_%s_%s"%(s,channel_name)).setConstant(1)
       rws.var("sigma2_%s_%s"%(s,channel_name)).setConstant(1)
       rws.var("frac_%s_%s"%(s,channel_name)).setConstant(1)
        


    # and lets import the data obs too!
    datah = fin.Get("data_obs")
    dh1   = ROOT.RooDataHist("data_obs_%s"%(channel_name),"obs data",ROOT.RooArgList(mass),datah)
    getattr(rws,"import")(dh1)


    rws.Print()
    fout.WriteTObject(rws)
    fout.Close()

# %%
fIn = ROOT.TFile.Open("data/Inv_mass_gghasOneL_DNN_2_HL.root")
doFitAndCreateWorkspace(fIn,"gghasOneL_DNN_2_HL","roofit_Inv_mass_gghasOneL_DNN_2_HL.root")
# Out:
# Results peak -> GGHH, channel -> gghasOneL_DNN_2_HL
# ---------------------------------
# Results peak -> GGH, channel -> gghasOneL_DNN_2_HL
# ---------------------------------
# Results peak -> VBFH, channel -> gghasOneL_DNN_2_HL
# ---------------------------------
# Results peak -> VH, channel -> gghasOneL_DNN_2_HL
# ---------------------------------
# Results peak -> ttH, channel -> gghasOneL_DNN_2_HL
# ---------------------------------
# Results peak -> tHq, channel -> gghasOneL_DNN_2_HL
# ---------------------------------
#
# RooFit v3.60 -- Developed by Wouter Verkerke and David Kirkby
#                 Copyright (C) 2000-2013 NIKHEF, University of California & Stanford University
#                 All rights reserved, please read http://roofit.sourceforge.net/license.txt
#
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::mgg_gghasOneL_DNN_2_HL
# [#0] WARNING:InputArguments -- RooAbsPdf::fitTo(exp_gghasOneL_DNN_2_HL) WARNING: a likelihood fit is requested of what appears to be weighted data.
#        While the estimated values of the parameters will always be calculated taking the weights into account,
#        there are multiple ways to estimate the errors of the parameters. You are advised to make an
#        explicit choice for the error calculation:
#            - Either provide SumW2Error(true), to calculate a sum-of-weights-corrected HESSE error matrix
#              (error will be proportional to the number of events in MC).
#            - Or provide SumW2Error(false), to return errors from original HESSE error matrix
#              (which will be proportional to the sum of the weights, i.e., a dataset with <sum of weights> events).
#            - Or provide AsymptoticError(true), to use the asymptotically correct expression
#              (for details see https://arxiv.org/abs/1911.01303).
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_gghasOneL_DNN_2_HL  -5.00000e-02  2.10000e-02   -2.00000e-01  1.00000e-02
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD         500           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=79289.6 FROM MIGRAD    STATUS=INITIATE        4 CALLS           5 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_gghasOneL_DNN_2_HL  -5.00000e-02   2.10000e-02   2.24553e-01  -8.82137e+03
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=78560.6 FROM MIGRAD    STATUS=CONVERGED      15 CALLS          16 TOTAL
#                      EDM=5.6651e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_gghasOneL_DNN_2_HL  -3.50569e-02   3.73540e-04   8.39715e-04   1.73705e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  1    ERR DEF=0.5
#   1.395e-07
#  **********
#  **    7 **SET ERR         0.5
#  **********
#  **********
#  **    8 **SET PRINT           1
#  **********
#  **********
#  **    9 **HESSE         500
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=78560.6 FROM HESSE     STATUS=OK              5 CALLS          21 TOTAL
#                      EDM=5.66592e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  alpha_gghasOneL_DNN_2_HL  -3.50569e-02   3.73540e-04   1.67943e-04   6.07585e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  1    ERR DEF=0.5
#   1.395e-07
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(mc_gghasOneL_DNN_2_HL) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooExponential::exp_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::alpha_gghasOneL_DNN_2_HL
# [#1] INFO:Eval -- RooRealVar::setRange(mgg_gghasOneL_DNN_2_HL) new range named 'r1' created with bounds [123,127]
# [#0] WARNING:InputArguments -- RooAbsPdf::fitTo(gauss_GGHH_gghasOneL_DNN_2_HL) WARNING: a likelihood fit is requested of what appears to be weighted data.
#        While the estimated values of the parameters will always be calculated taking the weights into account,
#        there are multiple ways to estimate the errors of the parameters. You are advised to make an
#        explicit choice for the error calculation:
#            - Either provide SumW2Error(true), to calculate a sum-of-weights-corrected HESSE error matrix
#              (error will be proportional to the number of events in MC).
#            - Or provide SumW2Error(false), to return errors from original HESSE error matrix
#              (which will be proportional to the sum of the weights, i.e., a dataset with <sum of weights> events).
#            - Or provide AsymptoticError(true), to use the asymptotically correct expression
#              (for details see https://arxiv.org/abs/1911.01303).
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_gauss_GGHH_gghasOneL_DNN_2_HL_rdh_GGHH) constructing test statistic for sub-range named fitrange
# [#1] INFO:Eval -- RooRealVar::setRange(mgg_gghasOneL_DNN_2_HL) new range named 'NormalizationRangeForfitrange' created with bounds [100,180]
# [#1] INFO:Eval -- RooRealVar::setRange(mgg_gghasOneL_DNN_2_HL) new range named 'fit_nll_gauss_GGHH_gghasOneL_DNN_2_HL_rdh_GGHH' created with bounds [100,180]
# [#0] WARNING:Fitting -- None of the fit observables seem to know the range 'fitrange'. This means that the full range will be used.
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_gauss_GGHH_gghasOneL_DNN_2_HL_rdh_GGHH) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# [#1] INFO:Minization --  The following expressions will be evaluated in cache-and-track mode: (gauss1_GGHH_gghasOneL_DNN_2_HL,gauss2_GGHH_gghasOneL_DNN_2_HL)
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 frac_GGHH_gghasOneL_DNN_2_HL   6.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      2 mh_GGHH_gghasOneL_DNN_2_HL   1.25000e+02  4.00000e-01    1.23000e+02  1.27000e+02
#      3 sigma1_GGHH_gghasOneL_DNN_2_HL   2.00000e+00  5.50000e-01    5.00000e-01  6.00000e+00
#      4 sigma2_GGHH_gghasOneL_DNN_2_HL   4.00000e+00  8.50000e-01    5.00000e-01  9.00000e+00
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        2000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=4.46044 FROM MIGRAD    STATUS=INITIATE       14 CALLS          15 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  frac_GGHH_gghasOneL_DNN_2_HL   6.00000e-01   1.00000e-01   2.05758e-01  -6.11482e-02
#    2  mh_GGHH_gghasOneL_DNN_2_HL   1.25000e+02   4.00000e-01   2.01358e-01  -2.74462e-02
#    3  sigma1_GGHH_gghasOneL_DNN_2_HL   2.00000e+00   5.50000e-01   2.28102e-01   1.19716e-01
#    4  sigma2_GGHH_gghasOneL_DNN_2_HL   4.00000e+00   8.50000e-01   2.04758e-01  -2.37716e-01
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=4.35671 FROM MIGRAD    STATUS=CONVERGED     129 CALLS         130 TOTAL
#                      EDM=6.76143e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  frac_GGHH_gghasOneL_DNN_2_HL   9.57722e-01   8.10370e-01   1.94789e-03  -1.92974e-03
#    2  mh_GGHH_gghasOneL_DNN_2_HL   1.25044e+02   1.66051e+00   1.48509e-03   2.04199e-03
#    3  sigma1_GGHH_gghasOneL_DNN_2_HL   2.45325e+00   1.66024e+00   8.87765e-04  -1.39261e-03
#    4  sigma2_GGHH_gghasOneL_DNN_2_HL   8.99232e+00   7.75385e+00   1.12802e-02  -8.26053e-04
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   8.974e-02  1.488e-02  2.708e-01  3.756e-02
#   1.488e-02  3.839e+00  1.019e-01  1.083e-03
#   2.708e-01  1.019e-01  3.227e+00  1.333e-01
#   3.756e-02  1.083e-03  1.333e-01  4.715e+00
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.50502   1.000  0.025  0.503  0.058
#         2  0.03155   0.025  1.000  0.029  0.000
#         3  0.50356   0.503  0.029  1.000  0.034
#         4  0.05805   0.058  0.000  0.034  1.000
#  **********
#  **    7 **SET ERR         0.5
#  **********
#  **********
#  **    8 **SET PRINT           1
#  **********
#  **********
#  **    9 **HESSE        2000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=4.35671 FROM HESSE     STATUS=OK             23 CALLS         153 TOTAL
#                      EDM=6.79035e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  frac_GGHH_gghasOneL_DNN_2_HL   9.57722e-01   8.10551e-01   3.89578e-04   1.15661e+00
#    2  mh_GGHH_gghasOneL_DNN_2_HL   1.25044e+02   1.66049e+00   2.97018e-04   2.19704e-02
#    3  sigma1_GGHH_gghasOneL_DNN_2_HL   2.45325e+00   1.66067e+00   1.77553e-04  -2.93942e-01
#    4  sigma2_GGHH_gghasOneL_DNN_2_HL   8.99232e+00   7.75855e+00   2.25604e-03   1.51067e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   8.983e-02  1.483e-02  2.713e-01  4.078e-02
#   1.483e-02  3.839e+00  9.993e-02  1.152e-03
#   2.713e-01  9.993e-02  3.229e+00  1.448e-01
#   4.078e-02  1.152e-03  1.448e-01  4.718e+00
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.50578   1.000  0.025  0.504  0.063
#         2  0.03112   0.025  1.000  0.028  0.000
#         3  0.50401   0.504  0.028  1.000  0.037
#         4  0.06299   0.063  0.000  0.037  1.000
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# RooRealVar::mh_GGHH_gghasOneL_DNN_2_HL = 125.044 +/- 1.66049  L(123 - 127)
# RooRealVar::sigma1_GGHH_gghasOneL_DNN_2_HL = 2.45325 +/- 1.66067  L(0.5 - 6)
# RooRealVar::sigma2_GGHH_gghasOneL_DNN_2_HL = 8.99232 +/- 7.75855  L(0.5 - 9)
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooAddPdf::gauss_GGHH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooGaussian::gauss1_GGHH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::mh_GGHH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::sigma1_GGHH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::frac_GGHH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooGaussian::gauss2_GGHH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::sigma2_GGHH_gghasOneL_DNN_2_HL
# [#1] INFO:InputArguments -- RooAbsData::plotOn(rdh_GGHH) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_GGHH_gghasOneL_DNN_2_HL) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_GGHH_gghasOneL_DNN_2_HL) only plotting range 'fit_nll_gauss_GGHH_gghasOneL_DNN_2_HL_rdh_GGHH'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_GGHH_gghasOneL_DNN_2_HL) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_gauss_GGHH_gghasOneL_DNN_2_HL_rdh_GGHH'
# [#0] WARNING:InputArguments -- RooAbsPdf::fitTo(gauss_GGH_gghasOneL_DNN_2_HL) WARNING: a likelihood fit is requested of what appears to be weighted data.
#        While the estimated values of the parameters will always be calculated taking the weights into account,
#        there are multiple ways to estimate the errors of the parameters. You are advised to make an
#        explicit choice for the error calculation:
#            - Either provide SumW2Error(true), to calculate a sum-of-weights-corrected HESSE error matrix
#              (error will be proportional to the number of events in MC).
#            - Or provide SumW2Error(false), to return errors from original HESSE error matrix
#              (which will be proportional to the sum of the weights, i.e., a dataset with <sum of weights> events).
#            - Or provide AsymptoticError(true), to use the asymptotically correct expression
#              (for details see https://arxiv.org/abs/1911.01303).
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_gauss_GGH_gghasOneL_DNN_2_HL_rdh_GGH) constructing test statistic for sub-range named fitrange
# [#1] INFO:Eval -- RooRealVar::setRange(mgg_gghasOneL_DNN_2_HL) new range named 'fit_nll_gauss_GGH_gghasOneL_DNN_2_HL_rdh_GGH' created with bounds [100,180]
# [#0] WARNING:Fitting -- None of the fit observables seem to know the range 'fitrange'. This means that the full range will be used.
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_gauss_GGH_gghasOneL_DNN_2_HL_rdh_GGH) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# [#1] INFO:Minization --  The following expressions will be evaluated in cache-and-track mode: (gauss1_GGH_gghasOneL_DNN_2_HL,gauss2_GGH_gghasOneL_DNN_2_HL)
#  **********
#  **   10 **SET PRINT           1
#  **********
#  **********
#  **   11 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 frac_GGH_gghasOneL_DNN_2_HL   6.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      2 mh_GGH_gghasOneL_DNN_2_HL   1.25000e+02  4.00000e-01    1.23000e+02  1.27000e+02
#      3 sigma1_GGH_gghasOneL_DNN_2_HL   2.00000e+00  5.50000e-01    5.00000e-01  6.00000e+00
#      4 sigma2_GGH_gghasOneL_DNN_2_HL   4.00000e+00  8.50000e-01    5.00000e-01  9.00000e+00
#  **********
#  **   12 **SET ERR         0.5
#  **********
#  **********
#  **   13 **SET PRINT           1
#  **********
#  **********
#  **   14 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   15 **MIGRAD        2000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=47.7871 FROM MIGRAD    STATUS=INITIATE       33 CALLS          34 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  frac_GGH_gghasOneL_DNN_2_HL   6.00000e-01   1.00000e-01   0.00000e+00   3.03441e+00
#    2  mh_GGH_gghasOneL_DNN_2_HL   1.25000e+02   4.00000e-01   0.00000e+00   1.29431e+01
#    3  sigma1_GGH_gghasOneL_DNN_2_HL   6.96489e-01   5.50000e-01  -7.18624e-01  -5.84318e-01
#    4  sigma2_GGH_gghasOneL_DNN_2_HL   4.00000e+00   8.50000e-01   0.00000e+00  -9.90861e-02
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=45.2541 FROM MIGRAD    STATUS=CONVERGED     122 CALLS         123 TOTAL
#                      EDM=1.52032e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  frac_GGH_gghasOneL_DNN_2_HL   4.19120e-01   1.48408e-01   1.35365e-03  -2.92090e-03
#    2  mh_GGH_gghasOneL_DNN_2_HL   1.24554e+02   2.26506e-01   5.26641e-04   7.39170e-03
#    3  sigma1_GGH_gghasOneL_DNN_2_HL   5.00000e-01   1.44502e-01   1.52427e-03** at limit **
#    4  sigma2_GGH_gghasOneL_DNN_2_HL   3.45982e+00   7.72527e-01   8.48013e-04  -1.83759e-03
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   2.272e-02  6.207e-03  1.835e-08  3.387e-02
#   6.207e-03  5.154e-02  6.018e-09  3.637e-02
#   1.835e-08  6.018e-09  6.789e-09  5.196e-08
#   3.387e-02  3.637e-02  5.196e-08  6.042e-01
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.31471   1.000  0.181  0.001  0.289
#         2  0.24221   0.181  1.000  0.000  0.206
#         3  0.00153   0.001  0.000  1.000  0.001
#         4  0.32857   0.289  0.206  0.001  1.000
#  **********
#  **   16 **SET ERR         0.5
#  **********
#  **********
#  **   17 **SET PRINT           1
#  **********
#  **********
#  **   18 **HESSE        2000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=45.2541 FROM HESSE     STATUS=OK             23 CALLS         146 TOTAL
#                      EDM=1.5192e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  frac_GGH_gghasOneL_DNN_2_HL   4.19120e-01   1.48428e-01   2.70730e-04  -1.62474e-01
#    2  mh_GGH_gghasOneL_DNN_2_HL   1.24554e+02   2.26532e-01   1.05328e-04  -2.24859e-01
#    3  sigma1_GGH_gghasOneL_DNN_2_HL   5.00000e-01   1.44502e-01   3.04855e-04  -1.57089e+00
#                                  WARNING -   - ABOVE PARAMETER IS AT LIMIT.
#    4  sigma2_GGH_gghasOneL_DNN_2_HL   3.45982e+00   7.72626e-01   1.69603e-04  -3.08439e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   2.273e-02  6.224e-03  1.654e-09  3.391e-02
#   6.224e-03  5.155e-02  5.413e-10  3.643e-02
#   1.654e-09  5.413e-10  6.789e-09  4.685e-09
#   3.391e-02  3.643e-02  4.685e-09  6.043e-01
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.31511   1.000  0.182  0.000  0.289
#         2  0.24265   0.182  1.000  0.000  0.206
#         3  0.00014   0.000  0.000  1.000  0.000
#         4  0.32892   0.289  0.206  0.000  1.000
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# RooRealVar::mh_GGH_gghasOneL_DNN_2_HL = 124.554 +/- 0.226532  L(123 - 127)
# RooRealVar::sigma1_GGH_gghasOneL_DNN_2_HL = 0.5 +/- 0.144502  L(0.5 - 6)
# RooRealVar::sigma2_GGH_gghasOneL_DNN_2_HL = 3.45982 +/- 0.772626  L(0.5 - 9)
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooAddPdf::gauss_GGH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooGaussian::gauss1_GGH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::mh_GGH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::sigma1_GGH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::frac_GGH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooGaussian::gauss2_GGH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::sigma2_GGH_gghasOneL_DNN_2_HL
# [#1] INFO:InputArguments -- RooAbsData::plotOn(rdh_GGH) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_GGH_gghasOneL_DNN_2_HL) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_GGH_gghasOneL_DNN_2_HL) only plotting range 'fit_nll_gauss_GGH_gghasOneL_DNN_2_HL_rdh_GGH'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_GGH_gghasOneL_DNN_2_HL) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_gauss_GGH_gghasOneL_DNN_2_HL_rdh_GGH'
# [#0] WARNING:InputArguments -- RooAbsPdf::fitTo(gauss_VBFH_gghasOneL_DNN_2_HL) WARNING: a likelihood fit is requested of what appears to be weighted data.
#        While the estimated values of the parameters will always be calculated taking the weights into account,
#        there are multiple ways to estimate the errors of the parameters. You are advised to make an
#        explicit choice for the error calculation:
#            - Either provide SumW2Error(true), to calculate a sum-of-weights-corrected HESSE error matrix
#              (error will be proportional to the number of events in MC).
#            - Or provide SumW2Error(false), to return errors from original HESSE error matrix
#              (which will be proportional to the sum of the weights, i.e., a dataset with <sum of weights> events).
#            - Or provide AsymptoticError(true), to use the asymptotically correct expression
#              (for details see https://arxiv.org/abs/1911.01303).
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_gauss_VBFH_gghasOneL_DNN_2_HL_rdh_VBFH) constructing test statistic for sub-range named fitrange
# [#1] INFO:Eval -- RooRealVar::setRange(mgg_gghasOneL_DNN_2_HL) new range named 'fit_nll_gauss_VBFH_gghasOneL_DNN_2_HL_rdh_VBFH' created with bounds [100,180]
# [#0] WARNING:Fitting -- None of the fit observables seem to know the range 'fitrange'. This means that the full range will be used.
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_gauss_VBFH_gghasOneL_DNN_2_HL_rdh_VBFH) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# [#1] INFO:Minization --  The following expressions will be evaluated in cache-and-track mode: (gauss1_VBFH_gghasOneL_DNN_2_HL,gauss2_VBFH_gghasOneL_DNN_2_HL)
#  **********
#  **   19 **SET PRINT           1
#  **********
#  **********
#  **   20 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 frac_VBFH_gghasOneL_DNN_2_HL   6.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      2 mh_VBFH_gghasOneL_DNN_2_HL   1.25000e+02  4.00000e-01    1.23000e+02  1.27000e+02
#      3 sigma1_VBFH_gghasOneL_DNN_2_HL   2.00000e+00  5.50000e-01    5.00000e-01  6.00000e+00
#      4 sigma2_VBFH_gghasOneL_DNN_2_HL   4.00000e+00  8.50000e-01    5.00000e-01  9.00000e+00
#  **********
#  **   21 **SET ERR         0.5
#  **********
#  **********
#  **   22 **SET PRINT           1
#  **********
#  **********
#  **   23 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   24 **MIGRAD        2000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=22.4327 FROM MIGRAD    STATUS=INITIATE       14 CALLS          15 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  frac_VBFH_gghasOneL_DNN_2_HL   6.00000e-01   1.00000e-01   2.05758e-01  -1.44040e-01
#    2  mh_VBFH_gghasOneL_DNN_2_HL   1.25000e+02   4.00000e-01   2.01358e-01   2.77826e-01
#    3  sigma1_VBFH_gghasOneL_DNN_2_HL   2.00000e+00   5.50000e-01   2.28102e-01   9.02074e-01
#    4  sigma2_VBFH_gghasOneL_DNN_2_HL   4.00000e+00   8.50000e-01   2.04758e-01  -5.68551e+00
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=20.5661 FROM MIGRAD    STATUS=CONVERGED     133 CALLS         134 TOTAL
#                      EDM=2.29908e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  frac_VBFH_gghasOneL_DNN_2_HL   8.58955e-01   1.86961e-01   1.58526e-03   1.42245e-03
#    2  mh_VBFH_gghasOneL_DNN_2_HL   1.25167e+02   8.45849e-01   1.35551e-03  -4.05889e-03
#    3  sigma1_VBFH_gghasOneL_DNN_2_HL   2.04867e+00   8.24969e-01   9.43399e-04   1.08210e-02
#    4  sigma2_VBFH_gghasOneL_DNN_2_HL   8.99994e+00   7.58090e+00   6.90159e-03  -1.12178e-03
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   3.895e-02  3.047e-02  7.731e-02  1.415e-05
#   3.047e-02  7.631e-01  1.414e-01  2.448e-05
#   7.731e-02  1.414e-01  7.074e-01  4.120e-05
#   1.415e-05  2.448e-05  4.120e-05  2.367e-03
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.47412   1.000  0.177  0.466  0.001
#         2  0.21618   0.177  1.000  0.192  0.001
#         3  0.47899   0.466  0.192  1.000  0.001
#         4  0.00154   0.001  0.001  0.001  1.000
#  **********
#  **   25 **SET ERR         0.5
#  **********
#  **********
#  **   26 **SET PRINT           1
#  **********
#  **********
#  **   27 **HESSE        2000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=20.5661 FROM HESSE     STATUS=OK             23 CALLS         157 TOTAL
#                      EDM=2.29635e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  frac_VBFH_gghasOneL_DNN_2_HL   8.58955e-01   1.86955e-01   3.17052e-04   8.00794e-01
#    2  mh_VBFH_gghasOneL_DNN_2_HL   1.25167e+02   8.45812e-01   2.71101e-04   8.34843e-02
#    3  sigma1_VBFH_gghasOneL_DNN_2_HL   2.04867e+00   8.24900e-01   1.88680e-04  -4.52089e-01
#    4  sigma2_VBFH_gghasOneL_DNN_2_HL   8.99994e+00   7.58098e+00   1.38032e-03   1.56552e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   3.895e-02  3.046e-02  7.729e-02  3.554e-05
#   3.046e-02  7.630e-01  1.412e-01  6.149e-05
#   7.729e-02  1.412e-01  7.073e-01  1.035e-04
#   3.554e-05  6.149e-05  1.035e-04  2.367e-03
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.47406   1.000  0.177  0.466  0.004
#         2  0.21597   0.177  1.000  0.192  0.001
#         3  0.47885   0.466  0.192  1.000  0.003
#         4  0.00387   0.004  0.001  0.003  1.000
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# RooRealVar::mh_VBFH_gghasOneL_DNN_2_HL = 125.167 +/- 0.845812  L(123 - 127)
# RooRealVar::sigma1_VBFH_gghasOneL_DNN_2_HL = 2.04867 +/- 0.8249  L(0.5 - 6)
# RooRealVar::sigma2_VBFH_gghasOneL_DNN_2_HL = 8.99994 +/- 7.58098  L(0.5 - 9)
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooAddPdf::gauss_VBFH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooGaussian::gauss1_VBFH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::mh_VBFH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::sigma1_VBFH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::frac_VBFH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooGaussian::gauss2_VBFH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::sigma2_VBFH_gghasOneL_DNN_2_HL
# [#1] INFO:InputArguments -- RooAbsData::plotOn(rdh_VBFH) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_VBFH_gghasOneL_DNN_2_HL) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_VBFH_gghasOneL_DNN_2_HL) only plotting range 'fit_nll_gauss_VBFH_gghasOneL_DNN_2_HL_rdh_VBFH'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_VBFH_gghasOneL_DNN_2_HL) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_gauss_VBFH_gghasOneL_DNN_2_HL_rdh_VBFH'
# [#0] WARNING:InputArguments -- RooAbsPdf::fitTo(gauss_VH_gghasOneL_DNN_2_HL) WARNING: a likelihood fit is requested of what appears to be weighted data.
#        While the estimated values of the parameters will always be calculated taking the weights into account,
#        there are multiple ways to estimate the errors of the parameters. You are advised to make an
#        explicit choice for the error calculation:
#            - Either provide SumW2Error(true), to calculate a sum-of-weights-corrected HESSE error matrix
#              (error will be proportional to the number of events in MC).
#            - Or provide SumW2Error(false), to return errors from original HESSE error matrix
#              (which will be proportional to the sum of the weights, i.e., a dataset with <sum of weights> events).
#            - Or provide AsymptoticError(true), to use the asymptotically correct expression
#              (for details see https://arxiv.org/abs/1911.01303).
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_gauss_VH_gghasOneL_DNN_2_HL_rdh_VH) constructing test statistic for sub-range named fitrange
# [#1] INFO:Eval -- RooRealVar::setRange(mgg_gghasOneL_DNN_2_HL) new range named 'fit_nll_gauss_VH_gghasOneL_DNN_2_HL_rdh_VH' created with bounds [100,180]
# [#0] WARNING:Fitting -- None of the fit observables seem to know the range 'fitrange'. This means that the full range will be used.
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_gauss_VH_gghasOneL_DNN_2_HL_rdh_VH) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# [#1] INFO:Minization --  The following expressions will be evaluated in cache-and-track mode: (gauss1_VH_gghasOneL_DNN_2_HL,gauss2_VH_gghasOneL_DNN_2_HL)
#  **********
#  **   28 **SET PRINT           1
#  **********
#  **********
#  **   29 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 frac_VH_gghasOneL_DNN_2_HL   6.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      2 mh_VH_gghasOneL_DNN_2_HL   1.25000e+02  4.00000e-01    1.23000e+02  1.27000e+02
#      3 sigma1_VH_gghasOneL_DNN_2_HL   2.00000e+00  5.50000e-01    5.00000e-01  6.00000e+00
#      4 sigma2_VH_gghasOneL_DNN_2_HL   4.00000e+00  8.50000e-01    5.00000e-01  9.00000e+00
#  **********
#  **   30 **SET ERR         0.5
#  **********
#  **********
#  **   31 **SET PRINT           1
#  **********
#  **********
#  **   32 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   33 **MIGRAD        2000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=172.139 FROM MIGRAD    STATUS=INITIATE       12 CALLS          13 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  frac_VH_gghasOneL_DNN_2_HL   6.00000e-01   1.00000e-01   2.05758e-01  -2.04704e+00
#    2  mh_VH_gghasOneL_DNN_2_HL   1.25000e+02   4.00000e-01   2.01358e-01  -1.10123e+00
#    3  sigma1_VH_gghasOneL_DNN_2_HL   2.00000e+00   5.50000e-01   2.28102e-01   4.18268e+00
#    4  sigma2_VH_gghasOneL_DNN_2_HL   4.00000e+00   8.50000e-01   2.04758e-01  -2.19150e+01
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=163.683 FROM MIGRAD    STATUS=CONVERGED     142 CALLS         143 TOTAL
#                      EDM=3.16692e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  frac_VH_gghasOneL_DNN_2_HL   9.42822e-01   4.92675e-02   1.73140e-03   1.71564e-02
#    2  mh_VH_gghasOneL_DNN_2_HL   1.25049e+02   3.15002e-01   1.39926e-03   2.50847e-02
#    3  sigma1_VH_gghasOneL_DNN_2_HL   2.38573e+00   2.70854e-01   8.40163e-04  -7.92455e-04
#    4  sigma2_VH_gghasOneL_DNN_2_HL   9.00000e+00   1.45045e+00   7.57062e-03  -1.82286e-03
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   2.465e-03  1.521e-04  5.472e-03 -3.749e-07
#   1.521e-04  1.001e-01  1.096e-03  2.646e-08
#   5.472e-03  1.096e-03  7.363e-02 -1.068e-06
#  -3.749e-07  2.646e-08 -1.068e-06  2.291e-05
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.40627   1.000  0.010  0.406 -0.002
#         2  0.01368   0.010  1.000  0.013  0.000
#         3  0.40634   0.406  0.013  1.000 -0.001
#         4  0.00159  -0.002  0.000 -0.001  1.000
#  **********
#  **   34 **SET ERR         0.5
#  **********
#  **********
#  **   35 **SET PRINT           1
#  **********
#  **********
#  **   36 **HESSE        2000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=163.683 FROM HESSE     STATUS=OK             23 CALLS         166 TOTAL
#                      EDM=3.16516e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  frac_VH_gghasOneL_DNN_2_HL   9.42822e-01   4.92773e-02   3.46280e-04   1.08788e+00
#    2  mh_VH_gghasOneL_DNN_2_HL   1.25049e+02   3.15000e-01   2.79853e-04   2.44116e-02
#    3  sigma1_VH_gghasOneL_DNN_2_HL   2.38573e+00   2.70907e-01   3.36065e-05  -3.19697e-01
#    4  sigma2_VH_gghasOneL_DNN_2_HL   9.00000e+00   1.45049e+00   1.51412e-03   1.56947e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   2.466e-03  1.518e-04  5.480e-03  8.620e-08
#   1.518e-04  1.001e-01  1.048e-03 -6.066e-09
#   5.480e-03  1.048e-03  7.366e-02  2.457e-07
#   8.620e-08 -6.066e-09  2.457e-07  2.291e-05
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.40668   1.000  0.010  0.407  0.000
#         2  0.01325   0.010  1.000  0.012 -0.000
#         3  0.40674   0.407  0.012  1.000  0.000
#         4  0.00037   0.000 -0.000  0.000  1.000
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# RooRealVar::mh_VH_gghasOneL_DNN_2_HL = 125.049 +/- 0.315  L(123 - 127)
# RooRealVar::sigma1_VH_gghasOneL_DNN_2_HL = 2.38573 +/- 0.270907  L(0.5 - 6)
# RooRealVar::sigma2_VH_gghasOneL_DNN_2_HL = 9 +/- 1.45049  L(0.5 - 9)
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooAddPdf::gauss_VH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooGaussian::gauss1_VH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::mh_VH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::sigma1_VH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::frac_VH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooGaussian::gauss2_VH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::sigma2_VH_gghasOneL_DNN_2_HL
# [#1] INFO:InputArguments -- RooAbsData::plotOn(rdh_VH) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_VH_gghasOneL_DNN_2_HL) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_VH_gghasOneL_DNN_2_HL) only plotting range 'fit_nll_gauss_VH_gghasOneL_DNN_2_HL_rdh_VH'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_VH_gghasOneL_DNN_2_HL) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_gauss_VH_gghasOneL_DNN_2_HL_rdh_VH'
# [#0] WARNING:InputArguments -- RooAbsPdf::fitTo(gauss_ttH_gghasOneL_DNN_2_HL) WARNING: a likelihood fit is requested of what appears to be weighted data.
#        While the estimated values of the parameters will always be calculated taking the weights into account,
#        there are multiple ways to estimate the errors of the parameters. You are advised to make an
#        explicit choice for the error calculation:
#            - Either provide SumW2Error(true), to calculate a sum-of-weights-corrected HESSE error matrix
#              (error will be proportional to the number of events in MC).
#            - Or provide SumW2Error(false), to return errors from original HESSE error matrix
#              (which will be proportional to the sum of the weights, i.e., a dataset with <sum of weights> events).
#            - Or provide AsymptoticError(true), to use the asymptotically correct expression
#              (for details see https://arxiv.org/abs/1911.01303).
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_gauss_ttH_gghasOneL_DNN_2_HL_rdh_ttH) constructing test statistic for sub-range named fitrange
# [#1] INFO:Eval -- RooRealVar::setRange(mgg_gghasOneL_DNN_2_HL) new range named 'fit_nll_gauss_ttH_gghasOneL_DNN_2_HL_rdh_ttH' created with bounds [100,180]
# [#0] WARNING:Fitting -- None of the fit observables seem to know the range 'fitrange'. This means that the full range will be used.
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_gauss_ttH_gghasOneL_DNN_2_HL_rdh_ttH) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# [#1] INFO:Minization --  The following expressions will be evaluated in cache-and-track mode: (gauss1_ttH_gghasOneL_DNN_2_HL,gauss2_ttH_gghasOneL_DNN_2_HL)
#  **********
#  **   37 **SET PRINT           1
#  **********
#  **********
#  **   38 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 frac_ttH_gghasOneL_DNN_2_HL   6.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      2 mh_ttH_gghasOneL_DNN_2_HL   1.25000e+02  4.00000e-01    1.23000e+02  1.27000e+02
#      3 sigma1_ttH_gghasOneL_DNN_2_HL   2.00000e+00  5.50000e-01    5.00000e-01  6.00000e+00
#      4 sigma2_ttH_gghasOneL_DNN_2_HL   4.00000e+00  8.50000e-01    5.00000e-01  9.00000e+00
#  **********
#  **   39 **SET ERR         0.5
#  **********
#  **********
#  **   40 **SET PRINT           1
#  **********
#  **********
#  **   41 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   42 **MIGRAD        2000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=86.7566 FROM MIGRAD    STATUS=INITIATE       12 CALLS          13 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  frac_ttH_gghasOneL_DNN_2_HL   6.00000e-01   1.00000e-01   2.05758e-01  -2.37053e-01
#    2  mh_ttH_gghasOneL_DNN_2_HL   1.25000e+02   4.00000e-01   2.01358e-01  -7.07619e-01
#    3  sigma1_ttH_gghasOneL_DNN_2_HL   2.00000e+00   5.50000e-01   2.28102e-01   9.21489e-01
#    4  sigma2_ttH_gghasOneL_DNN_2_HL   4.00000e+00   8.50000e-01   2.04758e-01  -1.91145e+01
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=80.0838 FROM MIGRAD    STATUS=CONVERGED     126 CALLS         127 TOTAL
#                      EDM=1.52893e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  frac_ttH_gghasOneL_DNN_2_HL   9.31577e-01   7.99233e-02   1.78571e-03  -2.47322e-03
#    2  mh_ttH_gghasOneL_DNN_2_HL   1.25059e+02   4.80087e-01   1.50278e-03   1.77922e-03
#    3  sigma1_ttH_gghasOneL_DNN_2_HL   2.48333e+00   4.27555e-01   9.01807e-04   2.33037e-03
#    4  sigma2_ttH_gghasOneL_DNN_2_HL   9.00000e+00   1.59589e+00   5.53657e-03** at limit **
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   6.613e-03  6.204e-04  1.552e-02 -2.623e-07
#   6.204e-04  2.351e-01  4.064e-03  1.883e-08
#   1.552e-02  4.064e-03  1.844e-01 -7.640e-07
#  -2.623e-07  1.883e-08 -7.640e-07  9.773e-06
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.44432   1.000  0.016  0.444 -0.001
#         2  0.02105   0.016  1.000  0.020  0.000
#         3  0.44444   0.444  0.020  1.000 -0.001
#         4  0.00104  -0.001  0.000 -0.001  1.000
#  **********
#  **   43 **SET ERR         0.5
#  **********
#  **********
#  **   44 **SET PRINT           1
#  **********
#  **********
#  **   45 **HESSE        2000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=80.0838 FROM HESSE     STATUS=OK             23 CALLS         150 TOTAL
#                      EDM=1.53012e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  frac_ttH_gghasOneL_DNN_2_HL   9.31577e-01   7.99397e-02   3.57143e-04   1.04148e+00
#    2  mh_ttH_gghasOneL_DNN_2_HL   1.25059e+02   4.80083e-01   3.00556e-04   2.93779e-02
#    3  sigma1_ttH_gghasOneL_DNN_2_HL   2.48333e+00   4.27641e-01   1.80361e-04  -2.82532e-01
#    4  sigma2_ttH_gghasOneL_DNN_2_HL   9.00000e+00   1.59591e+00   1.10731e-03   1.56998e+00
#                                  WARNING -   - ABOVE PARAMETER IS AT LIMIT.
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   6.616e-03  6.202e-04  1.553e-02  3.601e-08
#   6.202e-04  2.351e-01  3.956e-03 -2.593e-09
#   1.553e-02  3.956e-03  1.845e-01  1.050e-07
#   3.601e-08 -2.593e-09  1.050e-07  9.773e-06
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.44470   1.000  0.016  0.445  0.000
#         2  0.02066   0.016  1.000  0.019 -0.000
#         3  0.44480   0.445  0.019  1.000  0.000
#         4  0.00014   0.000 -0.000  0.000  1.000
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# RooRealVar::mh_ttH_gghasOneL_DNN_2_HL = 125.059 +/- 0.480083  L(123 - 127)
# RooRealVar::sigma1_ttH_gghasOneL_DNN_2_HL = 2.48333 +/- 0.427641  L(0.5 - 6)
# RooRealVar::sigma2_ttH_gghasOneL_DNN_2_HL = 9 +/- 1.59591  L(0.5 - 9)
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooAddPdf::gauss_ttH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooGaussian::gauss1_ttH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::mh_ttH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::sigma1_ttH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::frac_ttH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooGaussian::gauss2_ttH_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::sigma2_ttH_gghasOneL_DNN_2_HL
# [#1] INFO:InputArguments -- RooAbsData::plotOn(rdh_ttH) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_ttH_gghasOneL_DNN_2_HL) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_ttH_gghasOneL_DNN_2_HL) only plotting range 'fit_nll_gauss_ttH_gghasOneL_DNN_2_HL_rdh_ttH'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_ttH_gghasOneL_DNN_2_HL) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_gauss_ttH_gghasOneL_DNN_2_HL_rdh_ttH'
# [#0] WARNING:InputArguments -- RooAbsPdf::fitTo(gauss_tHq_gghasOneL_DNN_2_HL) WARNING: a likelihood fit is requested of what appears to be weighted data.
#        While the estimated values of the parameters will always be calculated taking the weights into account,
#        there are multiple ways to estimate the errors of the parameters. You are advised to make an
#        explicit choice for the error calculation:
#            - Either provide SumW2Error(true), to calculate a sum-of-weights-corrected HESSE error matrix
#              (error will be proportional to the number of events in MC).
#            - Or provide SumW2Error(false), to return errors from original HESSE error matrix
#              (which will be proportional to the sum of the weights, i.e., a dataset with <sum of weights> events).
#            - Or provide AsymptoticError(true), to use the asymptotically correct expression
#              (for details see https://arxiv.org/abs/1911.01303).
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_gauss_tHq_gghasOneL_DNN_2_HL_rdh_tHq) constructing test statistic for sub-range named fitrange
# [#1] INFO:Eval -- RooRealVar::setRange(mgg_gghasOneL_DNN_2_HL) new range named 'fit_nll_gauss_tHq_gghasOneL_DNN_2_HL_rdh_tHq' created with bounds [100,180]
# [#0] WARNING:Fitting -- None of the fit observables seem to know the range 'fitrange'. This means that the full range will be used.
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_gauss_tHq_gghasOneL_DNN_2_HL_rdh_tHq) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# [#1] INFO:Minization --  The following expressions will be evaluated in cache-and-track mode: (gauss1_tHq_gghasOneL_DNN_2_HL,gauss2_tHq_gghasOneL_DNN_2_HL)
#  **********
#  **   46 **SET PRINT           1
#  **********
#  **********
#  **   47 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 frac_tHq_gghasOneL_DNN_2_HL   6.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      2 mh_tHq_gghasOneL_DNN_2_HL   1.25000e+02  4.00000e-01    1.23000e+02  1.27000e+02
#      3 sigma1_tHq_gghasOneL_DNN_2_HL   2.00000e+00  5.50000e-01    5.00000e-01  6.00000e+00
#      4 sigma2_tHq_gghasOneL_DNN_2_HL   4.00000e+00  8.50000e-01    5.00000e-01  9.00000e+00
#  **********
#  **   48 **SET ERR         0.5
#  **********
#  **********
#  **   49 **SET PRINT           1
#  **********
#  **********
#  **   50 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   51 **MIGRAD        2000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=14.887 FROM MIGRAD    STATUS=INITIATE       14 CALLS          15 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  frac_tHq_gghasOneL_DNN_2_HL   6.00000e-01   1.00000e-01   2.05758e-01  -1.10748e-01
#    2  mh_tHq_gghasOneL_DNN_2_HL   1.25000e+02   4.00000e-01   2.01358e-01   6.91741e-03
#    3  sigma1_tHq_gghasOneL_DNN_2_HL   2.00000e+00   5.50000e-01   2.28102e-01   2.87403e-01
#    4  sigma2_tHq_gghasOneL_DNN_2_HL   4.00000e+00   8.50000e-01   2.04758e-01  -6.39115e-01
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=14.6928 FROM MIGRAD    STATUS=CONVERGED     151 CALLS         152 TOTAL
#                      EDM=0.000277182    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  frac_tHq_gghasOneL_DNN_2_HL   9.51933e-01   1.62877e-01   1.90877e-03   5.71511e-03
#    2  mh_tHq_gghasOneL_DNN_2_HL   1.24970e+02   1.05514e+00   1.50008e-03  -1.36200e-02
#    3  sigma1_tHq_gghasOneL_DNN_2_HL   2.51991e+00   1.03716e+00   9.08899e-04  -6.94584e-03
#    4  sigma2_tHq_gghasOneL_DNN_2_HL   8.95616e+00   8.12745e+00   1.80972e-02  -1.74517e-03
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   3.428e-02  4.017e-03  1.080e-01  2.723e-01
#   4.017e-03  1.235e+00  2.357e-02 -1.568e-03
#   1.080e-01  2.357e-02  1.136e+00  9.780e-01
#   2.723e-01 -1.568e-03  9.780e-01  2.805e+01
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.57805   1.000  0.020  0.547  0.278
#         2  0.02326   0.020  1.000  0.020 -0.000
#         3  0.54786   0.547  0.020  1.000  0.173
#         4  0.27896   0.278 -0.000  0.173  1.000
#  **********
#  **   52 **SET ERR         0.5
#  **********
#  **********
#  **   53 **SET PRINT           1
#  **********
#  **********
#  **   54 **HESSE        2000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=14.6928 FROM HESSE     STATUS=OK             23 CALLS         175 TOTAL
#                      EDM=0.000277832    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  frac_tHq_gghasOneL_DNN_2_HL   9.51933e-01   1.63484e-01   3.81755e-04   1.12872e+00
#    2  mh_tHq_gghasOneL_DNN_2_HL   1.24970e+02   1.05513e+00   3.00016e-04  -1.48475e-02
#    3  sigma1_tHq_gghasOneL_DNN_2_HL   2.51991e+00   1.03923e+00   1.81780e-04  -2.68709e-01
#    4  sigma2_tHq_gghasOneL_DNN_2_HL   8.95616e+00   8.17867e+00   3.61944e-03   1.42704e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   3.463e-02  3.989e-03  1.093e-01  2.906e-01
#   3.989e-03  1.235e+00  2.288e-02 -1.928e-03
#   1.093e-01  2.288e-02  1.140e+00  1.044e+00
#   2.906e-01 -1.928e-03  1.044e+00  2.834e+01
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.58382   1.000  0.019  0.550  0.293
#         2  0.02286   0.019  1.000  0.019 -0.000
#         3  0.55054   0.550  0.019  1.000  0.184
#         4  0.29461   0.293 -0.000  0.184  1.000
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# RooRealVar::mh_tHq_gghasOneL_DNN_2_HL = 124.97 +/- 1.05513  L(123 - 127)
# RooRealVar::sigma1_tHq_gghasOneL_DNN_2_HL = 2.51991 +/- 1.03923  L(0.5 - 6)
# RooRealVar::sigma2_tHq_gghasOneL_DNN_2_HL = 8.95616 +/- 8.17867  L(0.5 - 9)
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooAddPdf::gauss_tHq_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooGaussian::gauss1_tHq_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::mh_tHq_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::sigma1_tHq_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::frac_tHq_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooGaussian::gauss2_tHq_gghasOneL_DNN_2_HL
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing RooRealVar::sigma2_tHq_gghasOneL_DNN_2_HL
# [#1] INFO:InputArguments -- RooAbsData::plotOn(rdh_tHq) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_tHq_gghasOneL_DNN_2_HL) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_tHq_gghasOneL_DNN_2_HL) only plotting range 'fit_nll_gauss_tHq_gghasOneL_DNN_2_HL_rdh_tHq'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(gauss_tHq_gghasOneL_DNN_2_HL) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_gauss_tHq_gghasOneL_DNN_2_HL_rdh_tHq'
# [#1] INFO:ObjectHandling -- RooWorkspace::import(HHWWgg) importing dataset data_obs_gghasOneL_DNN_2_HL
#
# RooWorkspace(HHWWgg) HHWWgg contents
#
# variables
# ---------
# (alpha_gghasOneL_DNN_2_HL,frac_GGHH_gghasOneL_DNN_2_HL,frac_GGH_gghasOneL_DNN_2_HL,frac_VBFH_gghasOneL_DNN_2_HL,frac_VH_gghasOneL_DNN_2_HL,frac_tHq_gghasOneL_DNN_2_HL,frac_ttH_gghasOneL_DNN_2_HL,mgg_gghasOneL_DNN_2_HL,mh_GGHH_gghasOneL_DNN_2_HL,mh_GGH_gghasOneL_DNN_2_HL,mh_VBFH_gghasOneL_DNN_2_HL,mh_VH_gghasOneL_DNN_2_HL,mh_tHq_gghasOneL_DNN_2_HL,mh_ttH_gghasOneL_DNN_2_HL,sigma1_GGHH_gghasOneL_DNN_2_HL,sigma1_GGH_gghasOneL_DNN_2_HL,sigma1_VBFH_gghasOneL_DNN_2_HL,sigma1_VH_gghasOneL_DNN_2_HL,sigma1_tHq_gghasOneL_DNN_2_HL,sigma1_ttH_gghasOneL_DNN_2_HL,sigma2_GGHH_gghasOneL_DNN_2_HL,sigma2_GGH_gghasOneL_DNN_2_HL,sigma2_VBFH_gghasOneL_DNN_2_HL,sigma2_VH_gghasOneL_DNN_2_HL,sigma2_tHq_gghasOneL_DNN_2_HL,sigma2_ttH_gghasOneL_DNN_2_HL)
#
# p.d.f.s
# -------
# RooExponential::exp_gghasOneL_DNN_2_HL[ x=mgg_gghasOneL_DNN_2_HL c=alpha_gghasOneL_DNN_2_HL ] = 0.0124989
# RooGaussian::gauss1_GGHH_gghasOneL_DNN_2_HL[ x=mgg_gghasOneL_DNN_2_HL mean=mh_GGHH_gghasOneL_DNN_2_HL sigma=sigma1_GGHH_gghasOneL_DNN_2_HL ] = 0.99984
# RooGaussian::gauss1_GGH_gghasOneL_DNN_2_HL[ x=mgg_gghasOneL_DNN_2_HL mean=mh_GGH_gghasOneL_DNN_2_HL sigma=sigma1_GGH_gghasOneL_DNN_2_HL ] = 0.671848
# RooGaussian::gauss1_VBFH_gghasOneL_DNN_2_HL[ x=mgg_gghasOneL_DNN_2_HL mean=mh_VBFH_gghasOneL_DNN_2_HL sigma=sigma1_VBFH_gghasOneL_DNN_2_HL ] = 0.996692
# RooGaussian::gauss1_VH_gghasOneL_DNN_2_HL[ x=mgg_gghasOneL_DNN_2_HL mean=mh_VH_gghasOneL_DNN_2_HL sigma=sigma1_VH_gghasOneL_DNN_2_HL ] = 0.999791
# RooGaussian::gauss1_tHq_gghasOneL_DNN_2_HL[ x=mgg_gghasOneL_DNN_2_HL mean=mh_tHq_gghasOneL_DNN_2_HL sigma=sigma1_tHq_gghasOneL_DNN_2_HL ] = 0.999931
# RooGaussian::gauss1_ttH_gghasOneL_DNN_2_HL[ x=mgg_gghasOneL_DNN_2_HL mean=mh_ttH_gghasOneL_DNN_2_HL sigma=sigma1_ttH_gghasOneL_DNN_2_HL ] = 0.99972
# RooGaussian::gauss2_GGHH_gghasOneL_DNN_2_HL[ x=mgg_gghasOneL_DNN_2_HL mean=mh_GGHH_gghasOneL_DNN_2_HL sigma=sigma2_GGHH_gghasOneL_DNN_2_HL ] = 0.999988
# RooGaussian::gauss2_GGH_gghasOneL_DNN_2_HL[ x=mgg_gghasOneL_DNN_2_HL mean=mh_GGH_gghasOneL_DNN_2_HL sigma=sigma2_GGH_gghasOneL_DNN_2_HL ] = 0.991728
# RooGaussian::gauss2_VBFH_gghasOneL_DNN_2_HL[ x=mgg_gghasOneL_DNN_2_HL mean=mh_VBFH_gghasOneL_DNN_2_HL sigma=sigma2_VBFH_gghasOneL_DNN_2_HL ] = 0.999828
# RooGaussian::gauss2_VH_gghasOneL_DNN_2_HL[ x=mgg_gghasOneL_DNN_2_HL mean=mh_VH_gghasOneL_DNN_2_HL sigma=sigma2_VH_gghasOneL_DNN_2_HL ] = 0.999985
# RooGaussian::gauss2_tHq_gghasOneL_DNN_2_HL[ x=mgg_gghasOneL_DNN_2_HL mean=mh_tHq_gghasOneL_DNN_2_HL sigma=sigma2_tHq_gghasOneL_DNN_2_HL ] = 0.999995
# RooGaussian::gauss2_ttH_gghasOneL_DNN_2_HL[ x=mgg_gghasOneL_DNN_2_HL mean=mh_ttH_gghasOneL_DNN_2_HL sigma=sigma2_ttH_gghasOneL_DNN_2_HL ] = 0.999979
# RooAddPdf::gauss_GGHH_gghasOneL_DNN_2_HL[ frac_GGHH_gghasOneL_DNN_2_HL * gauss1_GGHH_gghasOneL_DNN_2_HL + [%] * gauss2_GGHH_gghasOneL_DNN_2_HL ] = 0.999846
# RooAddPdf::gauss_GGH_gghasOneL_DNN_2_HL[ frac_GGH_gghasOneL_DNN_2_HL * gauss1_GGH_gghasOneL_DNN_2_HL + [%] * gauss2_GGH_gghasOneL_DNN_2_HL ] = 0.85766
# RooAddPdf::gauss_VBFH_gghasOneL_DNN_2_HL[ frac_VBFH_gghasOneL_DNN_2_HL * gauss1_VBFH_gghasOneL_DNN_2_HL + [%] * gauss2_VBFH_gghasOneL_DNN_2_HL ] = 0.997134
# RooAddPdf::gauss_VH_gghasOneL_DNN_2_HL[ frac_VH_gghasOneL_DNN_2_HL * gauss1_VH_gghasOneL_DNN_2_HL + [%] * gauss2_VH_gghasOneL_DNN_2_HL ] = 0.999802
# RooAddPdf::gauss_tHq_gghasOneL_DNN_2_HL[ frac_tHq_gghasOneL_DNN_2_HL * gauss1_tHq_gghasOneL_DNN_2_HL + [%] * gauss2_tHq_gghasOneL_DNN_2_HL ] = 0.999934
# RooAddPdf::gauss_ttH_gghasOneL_DNN_2_HL[ frac_ttH_gghasOneL_DNN_2_HL * gauss1_ttH_gghasOneL_DNN_2_HL + [%] * gauss2_ttH_gghasOneL_DNN_2_HL ] = 0.999738
#
# datasets
# --------
# RooDataHist::data_obs_gghasOneL_DNN_2_HL(mgg_gghasOneL_DNN_2_HL)
# Info in <TCanvas::Print>: pdf file background_fit_gghasOneL_DNN_2_HL.pdf has been created
# Info in <TCanvas::Print>: pdf file signal_mc_fit_GGHH_gghasOneL_DNN_2_HL.pdf has been created
# Info in <TCanvas::Print>: pdf file signal_mc_fit_GGH_gghasOneL_DNN_2_HL.pdf has been created
# Info in <TCanvas::Print>: pdf file signal_mc_fit_VBFH_gghasOneL_DNN_2_HL.pdf has been created
# Info in <TCanvas::Print>: pdf file signal_mc_fit_VH_gghasOneL_DNN_2_HL.pdf has been created
# Info in <TCanvas::Print>: pdf file signal_mc_fit_ttH_gghasOneL_DNN_2_HL.pdf has been created
# Info in <TCanvas::Print>: pdf file signal_mc_fit_tHq_gghasOneL_DNN_2_HL.pdf has been created
